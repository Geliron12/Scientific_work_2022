# %% [markdown]
# # LSTM  модель с механизмом внимания для генерации музыкальных последовательностей

# %%
from music21 import *
import glob

# %%
import music21

# %% [markdown]
# Партитура:

# %%
a = converter.parse('small_piano_data/alb_esp1.mid')
a.show()

# %% [markdown]
# Загружаем все музыкальные файлы

# %%
midif = []
for file in glob.glob("cello/*.mid"):
    print(file)
    try:
        midi = converter.parse(file).chordify()
        midif.append(midi)
    except KeyError:
        problem_files.append(file)
# Out:
# cello\cs1-1pre.mid
# cello\cs1-2all.mid
# cello\cs1-3cou.mid
# cello\cs1-4sar.mid
# cello\cs1-5men.mid
# cello\cs1-6gig.mid
# cello\cs2-1pre.mid
# cello\cs2-2all.mid
# cello\cs2-3cou.mid
# cello\cs2-4sar.mid
# cello\cs2-5men.mid
# cello\cs2-6gig.mid
# cello\cs3-1pre.mid
# cello\cs3-2all.mid
# cello\cs3-3cou.mid
# cello\cs3-4sar.mid
# cello\cs3-5bou.mid
# cello\cs3-6gig.mid
# cello\cs4-1pre.mid
# cello\cs4-2all.mid
# cello\cs4-3cou.mid
# cello\cs4-4sar.mid
# cello\cs4-5bou.mid
# cello\cs4-6gig.mid
# cello\cs5-1pre.mid
# cello\cs5-2all.mid
# cello\cs5-3cou.mid
# cello\cs5-4sar.mid
# cello\cs5-5gav.mid
# cello\cs5-6gig.mid
# cello\cs6-1pre.mid
# cello\cs6-2all.mid
# cello\cs6-3cou.mid
# cello\cs6-4sar.mid
# cello\cs6-5gav.mid
# cello\cs6-6gig.mid

# %% [markdown]
# Создаем списки нот и длительностей по всем произведениям,возьмем длительность последовательностей в 32 ноты.

# %%
seq_len = 32
notes = []
durations = []
data = []

for midi in midif:
    notes = []
    durations = []
    notes_to_parse = midi.flat.notes
    ## для каждого трека добавляем индикатор старта
    notes.extend(['<START>']*seq_len)
    durations.extend(['<START>']*seq_len)
    ##добавляем в списки ноты и длительности
    for element in notes_to_parse:
        if isinstance(element, note.Note): ##если это нота то добавляем высоту в строковом формате
            if element.isRest:
                notes.append(str(element.name))
                durations.append(element.duration.quarterLength)
            else:
                notes.append(str(element.nameWithOctave))
            
                durations.append(element.duration.quarterLength)
        elif isinstance(element, chord.Chord):##если это аккорд, то добавляем информацию как из аккорда
            notes.append('.'.join(str(n) for n in element.pitches))
            durations.append(element.duration.quarterLength)
    ##общий массив данных
    data.append([notes,durations])

# %%
midis = data

# %%
seq_len = 32
all_notes = set()
all_durs = set()
for elem in midis:
    all_notes.update(elem[0])
    all_durs.update(elem[1])

# %% [markdown]
# Сохраняем

# %%
import pickle
with open("cello_model/all_notes", "wb") as fp:   
    pickle.dump(all_notes, fp)
with open("cello_model/all_durs", "wb") as fp:   
    pickle.dump(all_durs, fp)
with open("cello_model/midis", "wb") as fp:   
    pickle.dump(midis, fp)

# %% [markdown]
# Загружаем

# %%
import pickle
with open("cello_model/all_notes", "rb") as fp:   
    all_notes = pickle.load(fp)
with open("cello_model/all_durs", "rb") as fp:   
    all_durs = pickle.load(fp)
with open("cello_model/midis", "rb") as fp:   
    midis = pickle.load(fp)

# %% [markdown]
# Множества всех нот и длительностей

# %%
all_notes
# Out:
# {'<START>',
#  'A2',
#  'A2.A3',
#  'A2.B-3',
#  'A2.B2',
#  'A2.C3',
#  'A2.D3',
#  'A2.E-3',
#  'A2.E3',
#  'A2.E3.A3',
#  'A2.E3.C#4',
#  'A2.E3.C#4.A4',
#  'A2.E3.C#4.E4',
#  'A2.E3.C#4.G#4',
#  'A2.E3.C4',
#  'A2.E3.D4',
#  'A2.F#3',
#  'A2.F#3.C4',
#  'A2.F#3.D4',
#  'A2.F#3.D4.A4',
#  'A2.F#3.D4.E4',
#  'A2.F#3.D4.F#4',
#  'A2.F#4',
#  'A2.F3',
#  'A2.F3.C4',
#  'A2.F3.D4',
#  'A2.F3.D4.A4',
#  'A2.G3',
#  'A2.G3.C#4',
#  'A2.G3.D4',
#  'A3',
#  'A3.B-3',
#  'A3.B3',
#  'A3.B3.C#4',
#  'A3.B3.C#4.D4',
#  'A3.B3.C4',
#  'A3.C#4',
#  'A3.C#4.E4',
#  'A3.C4',
#  'A3.D4',
#  'A3.E4',
#  'A3.E4.F#4',
#  'A3.E4.G4',
#  'A3.F#4',
#  'A3.F#4.G4',
#  'A3.F4',
#  'A3.G4',
#  'A4',
#  'A4.B4',
#  'B-2',
#  'B-2.A3',
#  'B-2.B-3',
#  'B-2.C3',
#  'B-2.D3',
#  'B-2.D3.A3',
#  'B-2.D3.E-3.G#3',
#  'B-2.D3.G#3',
#  'B-2.E-3',
#  'B-2.E3',
#  'B-2.E3.D4',
#  'B-2.F#3.C#4.E4',
#  'B-2.F3',
#  'B-2.F3.C4',
#  'B-2.F3.D4',
#  'B-2.F3.E-4',
#  'B-2.G#3',
#  'B-2.G3',
#  'B-2.G3.D4',
#  'B-3',
#  'B-3.B3.E4',
#  'B-3.C4',
#  'B-4',
#  'B-4.B4.C#5.D5',
#  'B2',
#  'B2.A3',
#  'B2.C#3',
#  'B2.C3',
#  'B2.C3.D3',
#  'B2.D3',
#  'B2.D3.B3.F#4',
#  'B2.E-3',
#  'B2.E3.D4',
#  'B2.E3.E4',
#  'B2.F#3',
#  'B2.F#3.A3.B3.C4',
#  'B2.F#3.B3',
#  'B2.F#3.C4',
#  'B2.F#3.D4',
#  'B2.F#3.E-4',
#  'B2.F#3.E-4.A4',
#  'B2.F3',
#  'B2.G#3',
#  'B2.G#3.D4',
#  'B2.G3',
#  'B2.G3.D4',
#  'B3',
#  'B3.A4',
#  'B3.C#4',
#  'B3.C#4.D4',
#  'B3.C#4.D4.E4',
#  'B3.C4',
#  'B3.D4',
#  'B3.E4',
#  'B3.F#4',
#  'B3.F#4.G4',
#  'B3.F#4.G4.A4',
#  'B3.G#4.A4',
#  'B3.G4',
#  'B4',
#  'B4.C#5',
#  'B4.C5',
#  'B4.D5',
#  'C#2',
#  'C#2.B-2.F3',
#  'C#2.B-2.G3',
#  'C#3',
#  'C#3.D3',
#  'C#3.E3.A3',
#  'C#3.E3.B3.E4',
#  'C#3.F#3',
#  'C#3.G3',
#  'C#3.G3.A3',
#  'C#3.G3.B-3',
#  'C#4',
#  'C#4.A4',
#  'C#4.B4',
#  'C#4.D4',
#  'C#4.D4.E4',
#  'C#4.D4.F#4.B4',
#  'C#4.E4',
#  'C#4.E4.G#4.A4',
#  'C#4.F#4',
#  'C#5',
#  'C2',
#  'C2.A2.E-3',
#  'C2.A2.F#3',
#  'C2.A2.F#3.D4',
#  'C2.A2.F3.A3',
#  'C2.A2.G3.A3',
#  'C2.B-2',
#  'C2.B-2.E3',
#  'C2.B2.F3.G#3',
#  'C2.C3',
#  'C2.E-3',
#  'C2.E-3.G3',
#  'C2.E3.G3',
#  'C2.G#2',
#  'C2.G#2.D3.B3',
#  'C2.G2',
#  'C2.G2.D3',
#  'C2.G2.E-3',
#  'C2.G2.E-3.B-3',
#  'C2.G2.E-3.C4',
#  'C2.G2.E3',
#  'C2.G2.E3.B-3',
#  'C2.G2.E3.C4',
#  'C2.G2.F3',
#  'C2.G2.F3.C4',
#  'C3',
#  'C3.A3',
#  'C3.A3.E-4',
#  'C3.B-3',
#  'C3.D3',
#  'C3.D3.E3',
#  'C3.E-3',
#  'C3.E3',
#  'C3.E3.A3',
#  'C3.E3.B-3',
#  'C3.E3.B3',
#  'C3.E3.E4',
#  'C3.E3.F#4',
#  'C3.F#3',
#  'C3.F3',
#  'C3.G#3',
#  'C3.G#3.E-4',
#  'C3.G3',
#  'C3.G3.A3',
#  'C3.G3.B-3',
#  'C3.G3.C4',
#  'C3.G3.E-4',
#  'C4',
#  'C4.A4',
#  'C4.D4',
#  'C4.D4.E4.F#4',
#  'C4.E4',
#  'C4.F#4',
#  'C5',
#  'D2',
#  'D2.A2.D3',
#  'D2.A2.F#3',
#  'D2.A2.F#3.C#4',
#  'D2.A2.F#3.C4',
#  'D2.A2.F#3.D4',
#  'D2.A2.F3',
#  'D2.A2.F3.A3',
#  'D2.A2.F3.D4',
#  'D2.B-2.F3.G#3',
#  'D2.B-2.G#3',
#  'D2.B-2.G3.C4',
#  'D2.B-2.G3.D4',
#  'D2.B2',
#  'D2.B2.F3',
#  'D2.B2.G3',
#  'D2.C3.F#3.E-4',
#  'D2.E-3',
#  'D2.G2.F3.B3',
#  'D3',
#  'D3.A3',
#  'D3.A3.B3.C#4',
#  'D3.A3.F#4',
#  'D3.A3.G4',
#  'D3.A4',
#  'D3.B-3',
#  'D3.B3',
#  'D3.B3.G4',
#  'D3.C#4',
#  'D3.C#4.E4',
#  'D3.C#4.F#4',
#  'D3.C4',
#  'D3.C4.F#4',
#  'D3.D4',
#  'D3.E-3',
#  'D3.E-3.F3',
#  'D3.E-4',
#  'D3.E3',
#  'D3.E3.F#3',
#  'D3.E3.F#3.G3',
#  'D3.E4',
#  'D3.F#3',
#  'D3.F#4',
#  'D3.F3',
#  'D3.F3.A3',
#  'D3.F4',
#  'D3.G#3',
#  'D3.G3',
#  'D3.G3.A3',
#  'D3.G3.G#3',
#  'D3.G4',
#  'D4',
#  'D4.A4',
#  'D4.B4',
#  'D4.C5',
#  'D4.E-4',
#  'D4.E4',
#  'D4.E4.F#4',
#  'D4.E4.F#4.G4',
#  'D4.F#4',
#  'D4.F#4.G#4.A4',
#  'D4.G#4',
#  'D5',
#  'E-2',
#  'E-2.B-2.E-3',
#  'E-2.B-2.E-3.G3',
#  'E-2.B-2.F3',
#  'E-2.B-2.G#3',
#  'E-2.B-2.G3',
#  'E-2.B-2.G3.E-4',
#  'E-2.C3',
#  'E-2.G2',
#  'E-2.G2.D3',
#  'E-2.G2.G3.A3',
#  'E-2.G3',
#  'E-3',
#  'E-3.A3',
#  'E-3.A3.B3.C4',
#  'E-3.B-3',
#  'E-3.C#4',
#  'E-3.C4',
#  'E-3.C4.F#4',
#  'E-3.D4',
#  'E-3.F3',
#  'E-3.F3.G3.G#3',
#  'E-3.G#3',
#  'E-3.G3',
#  'E-3.G3.G#3',
#  'E-4',
#  'E-4.A4',
#  'E-4.E4',
#  'E-4.F#4',
#  'E-4.F4',
#  'E-5',
#  'E2',
#  'E2.B2.G#3.D4',
#  'E2.B2.G3',
#  'E2.C3.G3',
#  'E2.C3.G3.B-3',
#  'E2.E3.G3',
#  'E2.G2',
#  'E3',
#  'E3.A3',
#  'E3.B-3',
#  'E3.B3',
#  'E3.B3.A4',
#  'E3.B3.F#4',
#  'E3.B3.G4',
#  'E3.C#4',
#  'E3.C#4.D4',
#  'E3.C#4.D4.E4',
#  'E3.C#4.G4',
#  'E3.C4',
#  'E3.D4',
#  'E3.D4.A4.B4',
#  'E3.D4.E4',
#  'E3.D4.G#4',
#  'E3.F#3',
#  'E3.F#3.G#3.A3',
#  'E3.F#3.G3.B3',
#  'E3.F3',
#  'E3.G3',
#  'E4',
#  'E4.F#4',
#  'E4.F#4.G#4.A4',
#  'E4.F#4.G4',
#  'E4.F#4.G4.A4',
#  'E4.G4',
#  'E5',
#  'F#2',
#  'F#2.A2.D3.A3',
#  'F#2.A3',
#  'F#2.C3.E-3.C4',
#  'F#2.E3.C#4.E4',
#  'F#2.G2',
#  'F#3',
#  'F#3.A3',
#  'F#3.A3.E4',
#  'F#3.B3',
#  'F#3.B3.A4',
#  'F#3.C#4',
#  'F#3.C#4.A4',
#  'F#3.C#4.E4',
#  'F#3.C4',
#  'F#3.D4',
#  'F#3.D4.A4',
#  'F#3.G#3',
#  'F#3.G3',
#  'F#3.G3.A3',
#  'F#4',
#  'F#4.A4',
#  'F#4.B4',
#  'F#4.D5',
#  'F#4.G#4',
#  'F#4.G4',
#  'F#4.G4.A4',
#  'F#4.G4.B4',
#  'F#5',
#  'F2',
#  'F2.A2',
#  'F2.A2.D3',
#  'F2.A2.D3.A3',
#  'F2.A2.E3',
#  'F2.A3',
#  'F2.B-2',
#  'F2.B2.G3',
#  'F2.C3',
#  'F2.C3.D3',
#  'F2.C3.E-3',
#  'F2.C3.G#3',
#  'F2.D3.G#3',
#  'F2.G#2.D3',
#  'F2.G#2.E-3',
#  'F2.G2',
#  'F2.G2.D3.B3',
#  'F3',
#  'F3.A3',
#  'F3.B-3',
#  'F3.B3',
#  'F3.C4',
#  'F3.D4',
#  'F3.D4.G#4.B4',
#  'F3.E4',
#  'F3.G#3',
#  'F3.G3',
#  'F4',
#  'F4.F#4',
#  'F4.G#4',
#  'G#2',
#  'G#2.A2',
#  'G#2.B-2',
#  'G#2.D3',
#  'G#2.D3.B3',
#  'G#2.E-3',
#  'G#2.E-3.B-3',
#  'G#2.E-3.C#4',
#  'G#2.E-3.C4',
#  'G#2.E3.B3',
#  'G#2.E3.C#4',
#  'G#2.E3.D4',
#  'G#2.E3.D4.B4',
#  'G#2.F#4',
#  'G#2.F3',
#  'G#2.F3.B3',
#  'G#2.F3.C4',
#  'G#2.F3.D4',
#  'G#2.F3.E-4',
#  'G#2.G3',
#  'G#3',
#  'G#3.A3',
#  'G#3.A3.C#4',
#  'G#3.A3.D4',
#  'G#3.B-3',
#  'G#3.B3',
#  'G#3.D4',
#  'G#3.D4.E4',
#  'G#3.E4',
#  'G#3.F4',
#  'G#4',
#  'G#4.A4',
#  'G#4.B4',
#  'G2',
#  'G2.A3',
#  'G2.B-3',
#  'G2.B2',
#  'G2.B3',
#  'G2.B3.D4',
#  'G2.B3.G4',
#  'G2.C4',
#  'G2.D3',
#  'G2.D3.A3',
#  'G2.D3.A3.G4',
#  'G2.D3.B-3',
#  'G2.D3.B3',
#  'G2.D3.B3.A4',
#  'G2.D3.B3.F#4',
#  'G2.D3.C#4',
#  'G2.D3.C4',
#  'G2.D3.C4.G4',
#  'G2.D3.D4',
#  'G2.D3.G3',
#  'G2.E-3',
#  'G2.E-3.B-3',
#  'G2.E3',
#  'G2.E3.B3',
#  'G2.E3.C#4',
#  'G2.E3.C#4.A4',
#  'G2.E3.C4',
#  'G2.E3.D4',
#  'G2.E3.F3',
#  'G2.F#3',
#  'G2.F#3.D4',
#  'G2.F#3.E-4',
#  'G2.F3',
#  'G2.F3.B-3',
#  'G2.F3.B3',
#  'G2.F3.C4',
#  'G2.F3.D4',
#  'G2.F3.G3',
#  'G2.G#2',
#  'G2.G#2.B-2.C3',
#  'G2.G#3',
#  'G2.G3',
#  'G2.G3.B3.C#4',
#  'G2.G3.B3.E4',
#  'G2.G3.E4',
#  'G3',
#  'G3.A3',
#  'G3.A3.B3.C4',
#  'G3.B-3',
#  'G3.B3',
#  'G3.B3.B4',
#  'G3.B3.E4',
#  'G3.B3.F#4',
#  'G3.C#4',
#  'G3.C4',
#  'G3.D4',
#  'G3.D4.B4',
#  'G3.E-4',
#  'G3.E4',
#  'G4',
#  'G4.A4',
#  'G5'}

# %%
all_durs
# Out:
# {0.25,
#  0.5,
#  0.75,
#  1.0,
#  1.25,
#  1.5,
#  1.75,
#  Fraction(1, 12),
#  Fraction(1, 3),
#  Fraction(1, 6),
#  2.0,
#  2.5,
#  Fraction(2, 3),
#  3.0,
#  4.0,
#  Fraction(4, 3),
#  '<START>'}

# %%
len(all_notes)
# Out:
# 470

# %%
len(all_durs)
# Out:
# 17

# %% [markdown]
# Мэппинг нотам и длительностям целых чисел

# %%
note_to_int = dict((lnote, number) for number, lnote in enumerate(all_notes))

# %%
dur_to_int = dict((dur, number) for number, dur in enumerate(all_durs))

# %% [markdown]
# Создание датасета

# %%
import numpy as np

# %% [markdown]
# Для каждой последовательности ожидаемое сгенерированное значение - следующая нота и ее длительность

# %%
X_note = []
X_dur = []
Y_note = []
Y_dur = []
for nd in midis:
    for i in range(0,len(nd[0])-seq_len):
        for lnote,dur in zip(nd[0][i:i+seq_len],nd[1][i:i+seq_len]):
            X_note.append(note_to_int[lnote])
            X_dur.append(dur_to_int[dur])
        Y_note.append(note_to_int[nd[0][i+seq_len]])
        Y_dur.append(dur_to_int[nd[1][i+seq_len]])

# %%
#обучающие данные для нот
X_note = np.array(X_note).astype('float32').reshape((-1, seq_len,1))
X_note.shape
# Out:
# (27418, 32, 1)

# %%
#обучающие данные для длительностей
X_dur = np.array(X_dur).astype('float32').reshape((-1, seq_len,1))
X_dur.shape
# Out:
# (27418, 32, 1)

# %%
#лейблы нот
Y_note = np.array(Y_note).astype('float32').reshape(-1,1)
Y_note.shape
# Out:
# (27418, 1)

# %%
#лейблы длительностей
Y_dur = np.array(Y_dur).astype('float32').reshape(-1,1)
Y_dur.shape
# Out:
# (27418, 1)

# %% [markdown]
# Архитектура модели

# %%
from keras.layers import (Input, Embedding, Concatenate, LSTM, Dense, Reshape, 
                          Activation, Permute, Multiply, Lambda, Dropout, RepeatVector)
from keras.models import Model
from keras.optimizers import RMSprop,Adam
import keras.backend as K

# %%
notes_in = Input(shape = (None,))
durations_in = Input(shape = (None,))
x1 = Embedding(len(all_notes), 100)(notes_in)
x2 = Embedding(len(all_durs), 100)(durations_in)
x = Concatenate()([x1,x2]) 
x = LSTM(256, return_sequences=True)(x)
x = Dropout(0.3)(x)
x = LSTM(256, return_sequences=True)(x)
x = Dropout(0.3)(x)
##механизм внимания
e = Dense(1, activation='tanh')(x)
e = Reshape([-1])(e)
alpha = Activation('softmax')(e)
c = Permute([2, 1])(RepeatVector(256)(alpha))
c = Multiply()([x, c])
c = Lambda(lambda xin: K.sum(xin, axis=1), output_shape=(256,))(c)
#выходной слой
notes_out = Dense(len(all_notes), activation = 'softmax', name = 'pitch')(c)
durations_out = Dense(len(all_durs), activation = 'softmax', name = 'duration')(c)
model = Model([notes_in, durations_in], [notes_out, durations_out])
#модель только для рассмотрения работы механизма внимания
att_model = Model([notes_in, durations_in], alpha)
opti = Adam(learning_rate = 0.001)
model.compile(loss=['categorical_crossentropy', 'categorical_crossentropy'],
optimizer=opti)

# %%
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, None)]       0           []
#
#  input_6 (InputLayer)           [(None, None)]       0           []
#
#  embedding_4 (Embedding)        (None, None, 100)    47000       ['input_5[0][0]']
#
#  embedding_5 (Embedding)        (None, None, 100)    1700        ['input_6[0][0]']
#
#  concatenate_2 (Concatenate)    (None, None, 200)    0           ['embedding_4[0][0]',
#                                                                   'embedding_5[0][0]']
#
#  lstm_4 (LSTM)                  (None, None, 256)    467968      ['concatenate_2[0][0]']
#
#  dropout_4 (Dropout)            (None, None, 256)    0           ['lstm_4[0][0]']
#
#  lstm_5 (LSTM)                  (None, None, 256)    525312      ['dropout_4[0][0]']
#
#  dropout_5 (Dropout)            (None, None, 256)    0           ['lstm_5[0][0]']
#
#  dense_2 (Dense)                (None, None, 1)      257         ['dropout_5[0][0]']
#
#  reshape_2 (Reshape)            (None, None)         0           ['dense_2[0][0]']
#
#  activation_2 (Activation)      (None, None)         0           ['reshape_2[0][0]']
#
#  repeat_vector_2 (RepeatVector)  (None, 256, None)   0           ['activation_2[0][0]']
#
#  permute_2 (Permute)            (None, None, 256)    0           ['repeat_vector_2[0][0]']
#
#  multiply_2 (Multiply)          (None, None, 256)    0           ['dropout_5[0][0]',
#                                                                   'permute_2[0][0]']
#
#  lambda_2 (Lambda)              (None, 256)          0           ['multiply_2[0][0]']
#
#  pitch (Dense)                  (None, 470)          120790      ['lambda_2[0][0]']
#
#  duration (Dense)               (None, 17)           4369        ['lambda_2[0][0]']
#
# ==================================================================================================
# Total params: 1,167,396
# Trainable params: 1,167,396
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint

# %%
filepath = "big_lstm_cello.hdf5"
checkpoint = ModelCheckpoint(
    filepath, monitor='loss', 
    verbose=2,        
    save_best_only=True,        
    mode='min'
)

# %%
from keras.utils import to_categorical

# %% [markdown]
# Преобразовываем выходные значения к категориальным

# %%
Y_note_cat = to_categorical(Y_note, len(all_notes))
Y_dur_cat = to_categorical(Y_dur, len(all_durs))

# %% [markdown]
# Процесс обучения

# %%
callbacks_list = [checkpoint]     
history = model.fit([X_note, X_dur],[Y_note_cat, Y_dur_cat],epochs = 200, batch_size=64,
          validation_split = 0.1,shuffle = True, callbacks=callbacks_list)
# Out:
# Epoch 1/200
# 385/386 [============================>.] - ETA: 0s - loss: 4.3683 - pitch_loss: 3.6034 - duration_loss: 0.7648
# Epoch 1: loss improved from inf to 4.36811, saving model to big_lstm_cello.hdf5
# 386/386 [==============================] - 15s 28ms/step - loss: 4.3681 - pitch_loss: 3.6031 - duration_loss: 0.7650 - val_loss: 5.8923 - val_pitch_loss: 4.9553 - val_duration_loss: 0.9370
# Epoch 2/200
# 385/386 [============================>.] - ETA: 0s - loss: 3.9632 - pitch_loss: 3.3203 - duration_loss: 0.6429
# Epoch 2: loss improved from 4.36811 to 3.96458, saving model to big_lstm_cello.hdf5
# 386/386 [==============================] - 10s 25ms/step - loss: 3.9646 - pitch_loss: 3.3216 - duration_loss: 0.6430 - val_loss: 5.7104 - val_pitch_loss: 4.7474 - val_duration_loss: 0.9630
# Epoch 3/200
# 385/386 [============================>.] - ETA: 0s - loss: 3.8164 - pitch_loss: 3.2316 - duration_loss: 0.5849
# Epoch 3: loss improved from 3.96458 to 3.81646, saving model to big_lstm_cello.hdf5
# 386/386 [==============================] - 10s 25ms/step - loss: 3.8165 - pitch_loss: 3.2318 - duration_loss: 0.5847 - val_loss: 5.8046 - val_pitch_loss: 4.8419 - val_duration_loss: 0.9627
# Epoch 4/200
# 384/386 [============================>.] - ETA: 0s - loss: 3.6753 - pitch_loss: 3.1283 - duration_loss: 0.5470
# Epoch 4: loss improved from 3.81646 to 3.67555, saving model to big_lstm_cello.hdf5
# 386/386 [==============================] - 10s 25ms/step - loss: 3.6756 - pitch_loss: 3.1282 - duration_loss: 0.5473 - val_loss: 5.6557 - val_pitch_loss: 4.8517 - val_duration_loss: 0.8040
# Epoch 5/200
# 385/386 [============================>.] - ETA: 0s - loss: 3.5313 - pitch_loss: 3.0139 - duration_loss: 0.5174
# Epoch 5: loss improved from 3.67555 to 3.53236, saving model to big_lstm_cello.hdf5
# 386/386 [==============================] - 10s 25ms/step - loss: 3.5324 - pitch_loss: 3.0140 - duration_loss: 0.5184 - val_loss: 5.6547 - val_pitch_loss: 4.8451 - val_duration_loss: 0.8096
# Epoch 6/200
# 385/386 [============================>.] - ETA: 0s - loss: 3.4060 - pitch_loss: 2.9144 - duration_loss: 0.4916
# Epoch 6: loss improved from 3.53236 to 3.40667, saving model to big_lstm_cello.hdf5
# 386/386 [==============================] - 10s 25ms/step - loss: 3.4067 - pitch_loss: 2.9148 - duration_loss: 0.4919 - val_loss: 5.8108 - val_pitch_loss: 5.0434 - val_duration_loss: 0.7675
# Epoch 7/200
# 386/386 [==============================] - ETA: 0s - loss: 3.3005 - pitch_loss: 2.8285 - duration_loss: 0.4719
# Epoch 7: loss improved from 3.40667 to 3.30045, saving model to big_lstm_cello.hdf5
# 386/386 [==============================] - 10s 25ms/step - loss: 3.3005 - pitch_loss: 2.8285 - duration_loss: 0.4719 - val_loss: 5.9305 - val_pitch_loss: 5.0619 - val_duration_loss: 0.8686
# Epoch 8/200
# 385/386 [============================>.] - ETA: 0s - loss: 3.1928 - pitch_loss: 2.7459 - duration_loss: 0.4469
# Epoch 8: loss improved from 3.30045 to 3.19237, saving model to big_lstm_cello.hdf5
# 386/386 [==============================] - 9s 24ms/step - loss: 3.1924 - pitch_loss: 2.7455 - duration_loss: 0.4469 - val_loss: 5.9610 - val_pitch_loss: 5.1216 - val_duration_loss: 0.8394
# Epoch 9/200
# 384/386 [============================>.] - ETA: 0s - loss: 3.0759 - pitch_loss: 2.6544 - duration_loss: 0.4215
# Epoch 9: loss improved from 3.19237 to 3.07532, saving model to big_lstm_cello.hdf5
# 386/386 [==============================] - 9s 25ms/step - loss: 3.0753 - pitch_loss: 2.6543 - duration_loss: 0.4210 - val_loss: 6.0011 - val_pitch_loss: 5.1331 - val_duration_loss: 0.8679
# Epoch 10/200
# 385/386 [============================>.] - ETA: 0s - loss: 2.9632 - pitch_loss: 2.5644 - duration_loss: 0.3988
# Epoch 10: loss improved from 3.07532 to 2.96298, saving model to big_lstm_cello.hdf5
# 386/386 [==============================] - 10s 25ms/step - loss: 2.9630 - pitch_loss: 2.5641 - duration_loss: 0.3988 - val_loss: 6.1726 - val_pitch_loss: 5.3642 - val_duration_loss: 0.8084
# Epoch 11/200
# 385/386 [============================>.] - ETA: 0s - loss: 2.8536 - pitch_loss: 2.4798 - duration_loss: 0.3738
# Epoch 11: loss improved from 2.96298 to 2.85315, saving model to big_lstm_cello.hdf5
# 386/386 [==============================] - 10s 25ms/step - loss: 2.8531 - pitch_loss: 2.4796 - duration_loss: 0.3736 - val_loss: 6.3840 - val_pitch_loss: 5.4503 - val_duration_loss: 0.9337
# Epoch 12/200
# 384/386 [============================>.] - ETA: 0s - loss: 2.7390 - pitch_loss: 2.3877 - duration_loss: 0.3512
# Epoch 12: loss improved from 2.85315 to 2.73936, saving model to big_lstm_cello.hdf5
# 386/386 [==============================] - 10s 25ms/step - loss: 2.7394 - pitch_loss: 2.3879 - duration_loss: 0.3515 - val_loss: 6.6979 - val_pitch_loss: 5.7113 - val_duration_loss: 0.9866
# Epoch 13/200
# 386/386 [==============================] - ETA: 0s - loss: 2.6251 - pitch_loss: 2.2964 - duration_loss: 0.3287
# Epoch 13: loss improved from 2.73936 to 2.62507, saving model to big_lstm_cello.hdf5
# 386/386 [==============================] - 10s 25ms/step - loss: 2.6251 - pitch_loss: 2.2964 - duration_loss: 0.3287 - val_loss: 6.5077 - val_pitch_loss: 5.6117 - val_duration_loss: 0.8959
# Epoch 14/200
# 386/386 [==============================] - ETA: 0s - loss: 2.5203 - pitch_loss: 2.2089 - duration_loss: 0.3114
# Epoch 14: loss improved from 2.62507 to 2.52032, saving model to big_lstm_cello.hdf5
# 386/386 [==============================] - 10s 25ms/step - loss:
saving model to big_lstm_cello.hdf5
# 386/386 [==============================] - 9s 25ms/step - loss: 1.7222 - pitch_loss: 1.5462 - duration_loss: 0.1760 - val_loss: 7.8621 - val_pitch_loss: 6.6248 - val_duration_loss: 1.2373
# Epoch 23/200
# 384/386 [============================>.] - ETA: 0s - loss: 1.6303 - pitch_loss: 1.4693 - duration_loss: 0.1609
# Epoch 23: loss improved from 1.72218 to 1.63086, saving model to big_lstm_cello.hdf5
# 386/386 [==============================] - 9s 25ms/step - loss: 1.6309 - pitch_loss: 1.4700 - duration_loss: 0.1609 - val_loss: 7.9366 - val_pitch_loss: 6.6013 - val_duration_loss: 1.3354
# Epoch 24/200
# 385/386 [============================>.] - ETA: 0s - loss: 1.5486 - pitch_loss: 1.3964 - duration_loss: 0.1521
# Epoch 24: loss improved from 1.63086 to 1.54907, saving model to big_lstm_cello.hdf5
# 386/386 [==============================] - 9s 24ms/step - loss: 1.5491 - pitch_loss: 1.3968 - duration_loss: 0.1523 - val_loss: 8.1315 - val_pitch_loss: 6.7600 - val_duration_loss: 1.3715
# Epoch 25/200
# 385/386 [============================>.] - ETA: 0s - loss: 1.4701 - pitch_loss: 1.3266 - duration_loss: 0.1435
# Epoch 25: loss improved from 1.54907 to 1.47002, saving model to big_lstm_cello.hdf5
# 386/386 [==============================] - 9s 25ms/step - loss: 1.4700 - pitch_loss: 1.3267 - duration_loss: 0.1433 - val_loss: 8.0907 - val_pitch_loss: 6.7099 - val_duration_loss: 1.3808
# Epoch 26/200
# 384/386 [============================>.] - ETA: 0s - loss: 1.3942 - pitch_loss: 1.2600 - duration_loss: 0.1342
# Epoch 26: loss improved from 1.47002 to 1.39379, saving model to big_lstm_cello.hdf5
# 386/386 [==============================] - 10s 25ms/step - loss: 1.3938 - pitch_loss: 1.2597 - duration_loss: 0.1341 - val_loss: 8.3709 - val_pitch_loss: 6.8818 - val_duration_loss: 1.4891
# Epoch 27/200
# 384/386 [============================>.] - ETA: 0s - loss: 1.3371 - pitch_loss: 1.2100 - duration_loss: 0.1271
# Epoch 27: loss improved from 1.39379 to 1.33796, saving model to big_lstm_cello.hdf5
# 386/386 [==============================] - 10s 25ms/step - loss: 1.3380 - pitch_loss: 1.2107 - duration_loss: 0.1272 - val_loss: 8.7359 - val_pitch_loss: 7.1133 - val_duration_loss: 1.6226
# Epoch 28/200
# 385/386 [============================>.] - ETA: 0s - loss: 1.2640 - pitch_loss: 1.1436 - duration_loss: 0.1204
# Epoch 28: loss improved from 1.33796 to 1.26384, saving model to big_lstm_cello.hdf5
# 386/386 [==============================] - 10s 25ms/step - loss: 1.2638 - pitch_loss: 1.1435 - duration_loss: 0.1203 - val_loss: 8.9149 - val_pitch_loss: 7.3167 - val_duration_loss: 1.5983
# Epoch 29/200
# 386/386 [==============================] - ETA: 0s - loss: 1.1852 - pitch_loss: 1.0712 - duration_loss: 0.1140
# Epoch 29: loss improved from 1.26384 to 1.18518, saving model to big_lstm_cello.hdf5
# 386/386 [==============================] - 10s 25ms/step - loss: 1.1852 - pitch_loss: 1.0712 - duration_loss: 0.1140 - val_loss: 9.0988 - val_pitch_loss: 7.3629 - val_duration_loss: 1.7359
# Epoch 30/200
# 385/386 [============================>.] - ETA: 0s - loss: 1.1253 - pitch_loss: 1.0194 - duration_loss: 0.1059
# Epoch 30: loss improved from 1.18518 to 1.12515, saving model to big_lstm_cello.hdf5
# 386/386 [==============================] - 10s 25ms/step - loss: 1.1252 - pitch_loss: 1.0193 - duration_loss: 0.1058 - val_loss: 9.2110 - val_pitch_loss: 7.3811 - val_duration_loss: 1.8299
# Epoch 31/200
# 385/386 [============================>.] - ETA: 0s - loss: 1.0893 - pitch_loss: 0.9841 - duration_loss: 0.1052
# Epoch 31: loss improved from 1.12515 to 1.08920, saving model to big_lstm_cello.hdf5
# 386/386 [==============================] - 10s 25ms/step - loss:
200
# 386/386 [==============================] - ETA: 0s - loss: 0.2075 - pitch_loss: 0.1792 - duration_loss: 0.0284
# Epoch 194: loss did not improve from 0.19881
# 386/386 [==============================] - 10s 25ms/step - loss: 0.2075 - pitch_loss: 0.1792 - duration_loss: 0.0284 - val_loss: 14.8538 - val_pitch_loss: 11.7209 - val_duration_loss: 3.1329
# Epoch 195/200
# 386/386 [==============================] - ETA: 0s - loss: 0.2090 - pitch_loss: 0.1764 - duration_loss: 0.0327
# Epoch 195: loss did not improve from 0.19881
# 386/386 [==============================] - 10s 25ms/step - loss: 0.2090 - pitch_loss: 0.1764 - duration_loss: 0.0327 - val_loss: 14.5668 - val_pitch_loss: 11.4938 - val_duration_loss: 3.0729
# Epoch 196/200
# 384/386 [============================>.] - ETA: 0s - loss: 0.2135 - pitch_loss: 0.1820 - duration_loss: 0.0315
# Epoch 196: loss did not improve from 0.19881
# 386/386 [==============================] - 10s 25ms/step - loss: 0.2135 - pitch_loss: 0.1819 - duration_loss: 0.0316 - val_loss: 14.4253 - val_pitch_loss: 11.5749 - val_duration_loss: 2.8505
# Epoch 197/200
# 386/386 [==============================] - ETA: 0s - loss: 0.2096 - pitch_loss: 0.1779 - duration_loss: 0.0317
# Epoch 197: loss did not improve from 0.19881
# 386/386 [==============================] - 10s 25ms/step - loss: 0.2096 - pitch_loss: 0.1779 - duration_loss: 0.0317 - val_loss: 14.5107 - val_pitch_loss: 11.5022 - val_duration_loss: 3.0085
# Epoch 198/200
# 386/386 [==============================] - ETA: 0s - loss: 0.2359 - pitch_loss: 0.1980 - duration_loss: 0.0379
# Epoch 198: loss did not improve from 0.19881
# 386/386 [==============================] - 10s 26ms/step - loss: 0.2359 - pitch_loss: 0.1980 - duration_loss: 0.0379 - val_loss: 14.7145 - val_pitch_loss: 11.7021 - val_duration_loss: 3.0124
# Epoch 199/200
# 386/386 [==============================] - ETA: 0s - loss: 0.2288 - pitch_loss: 0.1935 - duration_loss: 0.0353
# Epoch 199: loss did not improve from 0.19881
# 386/386 [==============================] - 10s 25ms/step - loss: 0.2288 - pitch_loss: 0.1935 - duration_loss: 0.0353 - val_loss: 14.4892 - val_pitch_loss: 11.5441 - val_duration_loss: 2.9451
# Epoch 200/200
# 385/386 [============================>.] - ETA: 0s - loss: 0.2232 - pitch_loss: 0.1891 - duration_loss: 0.0341
# Epoch 200: loss did not improve from 0.19881
# 386/386 [==============================] - 10s 26ms/step - loss: 0.2233 - pitch_loss: 0.1892 - duration_loss: 0.0341 - val_loss: 14.1966 - val_pitch_loss: 11.3624 - val_duration_loss: 2.8342

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'pitch_loss', 'duration_loss', 'val_loss', 'val_pitch_loss', 'val_duration_loss'])

# %%
with open('history', 'wb') as file_pi:
    pickle.dump(history.history, file_pi)

# %%
import matplotlib.pyplot as plt

# %%
epochs = np.arange(1,201)
plt.plot(epochs, history.history['loss'])
epochs = np.arange(1,201)
plt.plot(epochs, history.history['val_loss'])
plt.legend(['loss','val_loss'])
plt.title('loss')
plt.xlabel('epochs')
plt.ylabel('losses')
plt.grid()

# %%
plt.plot(epochs, history.history['pitch_loss'])
plt.plot(epochs, history.history['duration_loss'])
plt.legend(['pitch_loss','duration_loss'])
plt.title('loss')
plt.xlabel('epochs')
plt.ylabel('losses')
plt.grid()

# %%
plt.plot(epochs, history.history['val_pitch_loss'])
plt.plot(epochs, history.history['val_duration_loss'])
plt.legend(['val_pitch_loss','val_duration_loss'])
plt.title('loss')
plt.xlabel('epochs')
plt.ylabel('losses')
plt.grid()

# %%
model.load_weights('big_lstm_cello.hdf5')

# %% [markdown]
# Словари для декодирования целых чисел в ноты и длительности

# %%
int_to_note = {y: x for x, y in note_to_int.items()}
int_to_dur = {y: x for x, y in dur_to_int.items()}

# %% [markdown]
# Функция предсказания с температурой(для решения проблемы детерминированных предсказаний)

# %%
def pred_with_temp(pred,temperature):
    if temperature == 0:
        return np.argmax(pred)
    else:
        pred = np.log(pred) / temperature
        exp_pred = np.exp(pred)
        pred = exp_pred / np.sum(exp_pred)
        return np.random.choice(len(pred), p=pred)

# %% [markdown]
# Функция для генерации примеров

# %%
def generate_sample(seq_len,temp_score=0.3):
    fnote = note_to_int['<START>']
    fdur = dur_to_int['<START>']

    temperature = 0.3

    #создаем входные последовательности из токенов старта
    note_seq = [fnote]*seq_len
    dur_seq = [fdur]*seq_len
    note_seq = np.array(note_seq).reshape(1,-1)
    dur_seq = np.array(dur_seq).reshape(1,-1)
    
    new_note = 0
    new_dur = 0
    i = 32
    pred_seq_note = note_seq
    pred_seq_dur = dur_seq
    #процесс создания последовательностей предсказаний модели (длиной 500)
    while note_seq.shape[1]!= 500+seq_len and new_note!=note_to_int['<START>'] and new_dur!=dur_to_int['<START>']:
        
        new_note, new_dur =  model.predict([pred_seq_note, pred_seq_dur],verbose=0)
        new_note = pred_with_temp(new_note[0],temperature)
        new_dur = pred_with_temp(new_dur[0],temperature)
        i+=1
        note_seq = np.append(note_seq,[[new_note]], axis= 1)
        dur_seq = np.append(dur_seq,[[new_dur]], axis= 1)
        note_seq = np.array(note_seq).reshape(1,-1)
        dur_seq = np.array(dur_seq).reshape(1,-1)
        pred_seq_note = note_seq[:,i-32:i]
        pred_seq_dur = dur_seq[:,i-32:i]
    note_text_seq = []
    dur_text_seq = []
    #декодируем
    for i in range(0,len(note_seq[0])):
        note_text_seq.append(int_to_note[note_seq[0][i]])
        dur_text_seq.append(int_to_dur[dur_seq[0][i]])

    return note_text_seq, dur_text_seq

# %% [markdown]
# Функция для создания самих midi-файлов

# %%
def create_midi(note_text_seq, dur_text_seq):
    midi_stream = stream.Stream()
    for note_pattern, duration_pattern in zip(note_text_seq, dur_text_seq):
        # pattern is a chord
        if ('.' in note_pattern):
            notes_in_chord = note_pattern.split('.')
            chord_notes = []
            for current_note in notes_in_chord:
                new_note = note.Note(current_note)
                new_note.duration = duration.Duration(duration_pattern)
                new_note.storedInstrument = instrument.Violoncello()
                chord_notes.append(new_note)
            new_chord = chord.Chord(chord_notes)
            midi_stream.append(new_chord)
        elif note_pattern == 'rest':
        # pattern is a rest
            new_note = note.Rest()
            new_note.duration = duration.Duration(duration_pattern)
            new_note.storedInstrument = instrument.Violoncello()
            midi_stream.append(new_note)
        elif note_pattern != '<START>':
        # pattern is a note
            new_note = note.Note(note_pattern)
            new_note.duration = duration.Duration(duration_pattern)
            new_note.storedInstrument = instrument.Violoncello()
            midi_stream.append(new_note)
    return midi_stream

# %% [markdown]
# Генерируем выходные семплы

# %%
for i in range(5):
    n,d = generate_sample(seq_len)
    midi_result = create_midi(n,d)
    midi_result.write('midi',fp = f'cello_out{i}.mid')

# %%
a = converter.parse(f'cello_out{0}.mid')
a.show()
